# %%
import pandas as pd

# %%
import os

# %%
all_entries = os.listdir('data/')
csv_files = [f for f in all_entries if f.endswith('.csv')]
csv_files
# Out:
# ['A.csv',
#  'AA.csv',
#  'AACB.csv',
#  'AACG.csv',
#  'AAL.csv',
#  'AAME.csv',
#  'AAMI.csv',
#  'AAOI.csv',
#  'AAON.csv',
#  'AAP.csv',
#  'AAPG.csv',
#  'AAPL.csv',
#  'AARD.csv',
#  'AAT.csv',
#  'AAUC.csv',
#  'AB.csv',
#  'ABAT.csv',
#  'ABBV.csv',
#  'ABCB.csv',
#  'ABCL.csv',
#  'ABEO.csv',
#  'ABEV.csv',
#  'ABG.csv',
#  'ABLV.csv',
#  'ABM.csv',
#  'ABNB.csv',
#  'ABOS.csv',
#  'ABP.csv',
#  'ABR.csv',
#  'ABSI.csv',
#  'ABT.csv',
#  'ABTC.csv',
#  'ABTS.csv',
#  'ABUS.csv',
#  'ABVC.csv',
#  'ABVE.csv',
#  'ABVX.csv',
#  'ABX.csv',
#  'ACA.csv',
#  'ACAD.csv',
#  'ACB.csv',
#  'ACCL.csv',
#  'ACCO.csv',
#  'ACCS.csv',
#  'ACDC.csv',
#  'ACEL.csv',
#  'ACET.csv',
#  'ACFN.csv',
#  'ACGL.csv',
#  'ACH.csv',
#  'ACHC.csv',
#  'ACHR.csv',
#  'ACHV.csv',
#  'ACI.csv',
#  'ACIC.csv',
#  'ACIU.csv',
#  'ACIW.csv',
#  'ACLS.csv',
#  'ACLX.csv',
#  'ACM.csv',
#  'ACMR.csv',
#  'ACN.csv',
#  'ACNB.csv',
#  'ACNT.csv',
#  'ACOG.csv',
#  'ACON.csv',
#  'ACR.csv',
#  'ACRE.csv',
# ...

# %%
df = pd.read_csv('data/A.csv')
df
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 0    2023-02-13  149.909063  151.268582  148.676683  151.209900   925400
# 1    2023-02-14  150.955609  152.334694  148.128982  149.684113   895400
# 2    2023-02-15  148.882104  148.979917  147.004208  148.422409   982400
# 3    2023-02-16  145.546896  146.867299  144.001540  145.028519  1101700
# 4    2023-02-17  144.030900  145.674069  143.277795  145.008972  1194800
# ..          ...         ...         ...         ...         ...      ...
# 748  2026-02-06  130.320007  131.429993  128.630005  129.580002  1931000
# 749  2026-02-09  127.790001  128.000000  125.680000  127.500000  2233500
# 750  2026-02-10  128.289993  129.979996  127.290001  129.000000  2124500
# 751  2026-02-11  128.029999  129.559998  127.139999  128.899994  2062400
# 752  2026-02-12  129.000000  129.000000  120.989998  124.879997  3431000
#
#      is_earnings_day  EPS Estimate  Reported EPS  Surprise(%)  \
# ...

# %%
df['ticker'] = 'A'
df
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 0    2023-02-13  149.909063  151.268582  148.676683  151.209900   925400
# 1    2023-02-14  150.955609  152.334694  148.128982  149.684113   895400
# 2    2023-02-15  148.882104  148.979917  147.004208  148.422409   982400
# 3    2023-02-16  145.546896  146.867299  144.001540  145.028519  1101700
# 4    2023-02-17  144.030900  145.674069  143.277795  145.008972  1194800
# ..          ...         ...         ...         ...         ...      ...
# 748  2026-02-06  130.320007  131.429993  128.630005  129.580002  1931000
# 749  2026-02-09  127.790001  128.000000  125.680000  127.500000  2233500
# 750  2026-02-10  128.289993  129.979996  127.290001  129.000000  2124500
# 751  2026-02-11  128.029999  129.559998  127.139999  128.899994  2062400
# 752  2026-02-12  129.000000  129.000000  120.989998  124.879997  3431000
#
#      is_earnings_day  EPS Estimate  Reported EPS  Surprise(%)  \
# ...

# %%
for i in csv_files:
    df2 = pd.read_csv(f'data/{i}')
    df2['ticker'] = i[:-4]
    df = pd.concat([df,df2])
    print(f'on ticker {i}')
df
# Out:
# on ticker A.csv
# on ticker AA.csv
# on ticker AACB.csv
# on ticker AACG.csv
# on ticker AAL.csv
# on ticker AAME.csv
# on ticker AAMI.csv
# on ticker AAOI.csv
# on ticker AAON.csv
# on ticker AAP.csv
# on ticker AAPG.csv
# on ticker AAPL.csv
# on ticker AARD.csv
# on ticker AAT.csv
# on ticker AAUC.csv
# on ticker AB.csv
# on ticker ABAT.csv
# on ticker ABBV.csv
# on ticker ABCB.csv
# on ticker ABCL.csv
# on ticker ABEO.csv
# on ticker ABEV.csv
# on ticker ABG.csv
# on ticker ABLV.csv
# on ticker ABM.csv
# on ticker ABNB.csv
# on ticker ABOS.csv
# on ticker ABP.csv
# on ticker ABR.csv
# on ticker ABSI.csv
# on ticker ABT.csv
# on ticker ABTC.csv
# on ticker ABTS.csv
# on ticker ABUS.csv
# on ticker ABVC.csv
# on ticker ABVE.csv
# on ticker ABVX.csv
# on ticker ABX.csv
# on ticker ACA.csv
# on ticker ACAD.csv
# on ticker ACB.csv
# on ticker ACCL.csv
# on ticker ACCO.csv
# on ticker ACCS.csv
# on ticker ACDC.csv
# on ticker ACEL.csv
# on ticker ACET.csv
# on ticker ACFN.csv
# ...

# %%
df
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 0    2023-02-13  149.909063  151.268582  148.676683  151.209900   925400
# 1    2023-02-14  150.955609  152.334694  148.128982  149.684113   895400
# 2    2023-02-15  148.882104  148.979917  147.004208  148.422409   982400
# 3    2023-02-16  145.546896  146.867299  144.001540  145.028519  1101700
# 4    2023-02-17  144.030900  145.674069  143.277795  145.008972  1194800
# ..          ...         ...         ...         ...         ...      ...
# 748  2026-02-06   22.379999   23.059999   22.340000   22.719999   575700
# 749  2026-02-09   22.520000   22.750000   22.245001   22.510000   602400
# 750  2026-02-10   22.790001   22.924999   22.250000   22.730000   490100
# 751  2026-02-11   22.650000   22.900000   22.070000   22.830000   681000
# 752  2026-02-12   23.010000   23.430000   22.459999   23.170000   448600
#
#      is_earnings_day  EPS Estimate  Reported EPS  Surprise(%)  \
# ...

# %%
df.to_csv('all_stock_info.csv')

# %%
ticks = df[df['Reported EPS']>df['EPS Estimate']]

# %%
ticks.groupby('ticker').count().sort_values(by='industry')
# Out:
#         Date  Open  High  Low  Close  Volume  is_earnings_day  EPS Estimate  \
# ticker
# ADAM       5     5     5    5      5       5                5             5
# ADAG       1     1     1    1      1       1                1             1
# ABVX       1     1     1    1      1       1                1             1
# ARTV       1     1     1    1      1       1                1             1
# AEBI       1     1     1    1      1       1                1             1
# ...      ...   ...   ...  ...    ...     ...              ...           ...
# ARW       12    12    12   12     12      12               12            12
# AMAT      13    13    13   13     13      13               13            13
# ANET      13    13    13   13     13      13               13            13
# ACGL      13    13    13   13     13      13               13            13
# A         22    22    22   22     22      22               22            22
#
#         Reported EPS  Surprise(%)  industry
# ...

# %%
earnings = df[df['is_earnings_day']==True]

# %%
decent = earnings[earnings['Surprise(%)']>10].sort_values(by='Surprise(%)')
decent = decent[decent['Surprise(%)']<50].sort_values(by='Surprise(%)')
decent
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 117  2023-08-02    7.366064    7.465701    7.202373    7.380298   1089900
# 684  2025-11-04  250.350006  257.380005  247.389999  250.050003  56491800
# 245  2024-02-05   87.127822   87.804374   86.353221   87.019966    975500
# 621  2025-08-06  130.675003  131.289993  128.300003  130.500000  11212800
# 679  2025-10-28  184.148169  184.544309  175.779602  180.959198   6047500
# ..          ...         ...         ...         ...         ...       ...
# 269  2024-03-11    2.210000    2.280000    2.170000    2.220000    873100
# 372  2024-08-07    7.385382    7.895583    7.385382    7.862127    236300
# 741  2026-01-28   23.860001   24.370001   23.730000   23.799999    190400
# 185  2023-11-07    4.180000    4.570000    4.130000    4.310000   2177900
# 62   2025-08-12   12.600000   12.625000   12.020000   12.400000     41500
#
#      is_earnings_day  EPS Estimate  Reported EPS  Surprise(%)  \
# ...

# %%
decent[decent['industry'].isin('')]
# Out:
#         Date  Open  High  Low  Close  Volume  is_earnings_day  EPS Estimate  \
# ticker
# ASPS       1     1     1    1      1       1                1             1
# ABP        1     1     1    1      1       1                1             1
# ABSI       1     1     1    1      1       1                1             1
# ARMK       1     1     1    1      1       1                1             1
# ARR        1     1     1    1      1       1                1             1
# ...      ...   ...   ...  ...    ...     ...              ...           ...
# AMWL       9     9     9    9      9       9                9             9
# AIZ       10    10    10   10     10      10               10            10
# ALRM      10    10    10   10     10      10               10            10
# ACEL      10    10    10   10     10      10               10            10
# ACGL      11    11    11   11     11      11               11            11
#
#         Reported EPS  Surprise(%)  industry
# ...

# %%
earnings[earnings['industry']=='Software - Application']
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 21   2023-03-15  330.000000  334.279999  328.170013  333.609985  4627100
# 85   2023-06-15  475.470001  495.200012  474.250000  490.910004  9682200
# 147  2023-09-14  551.090027  555.190002  544.340027  552.159973  4786900
# 210  2023-12-13  630.409973  632.450012  618.030029  624.260010  6188500
# 272  2024-03-14  578.000000  579.539978  568.760010  570.450012  5908100
# ..          ...         ...         ...         ...         ...      ...
# 456  2024-12-05   15.570000   15.940000   15.366000   15.460000  4497600
# 518  2025-03-10   17.480000   17.620001   16.440001   16.680000  8457700
# 577  2025-06-03   18.340000   19.000000   18.209999   19.000000  6884100
# 640  2025-09-03   13.860000   14.300000   13.682000   14.230000  9124600
# 703  2025-12-02   12.930000   13.670000   12.920000   13.390000  9292900
#
#      is_earnings_day  EPS Estimate  Reported EPS  Surprise(%)  \
# ...

# %%
we
# Out:
#      ticker                                    name  \
# 0         A              Agilent Technologies, Inc.
# 1        AA                       Alcoa Corporation
# 2      AACB              Artius II Acquisition Inc.
# 3      AACG                   ATA Creativity Global
# 4       AAL            American Airlines Group Inc.
# ...     ...                                     ...
# 5526   ZVIA                               Zevia PBC
# 5527   ZVRA                Zevra Therapeutics, Inc.
# 5528    ZWS  Zurn Elkay Water Solutions Corporation
# 5529   ZYBT   Zhengye Biotechnology Holding Limited
# 5530   ZYME                          Zymeworks Inc.
#
#                                       industry    marketCap
# 0                       Diagnostics & Research  35321013869
# 1                                     Aluminum  15950690203
# 2                              Shell Companies    287000820
# 3                Education & Training Services     38454209
# ...

# %%
we[we['industry']=='Software - Infrastructure']
# Out:
#      ticker                        name                   industry  \
# 56     ACIW         ACI Worldwide, Inc.  Software - Infrastructure
# 122    AEVA     Aeva Technologies, Inc.  Software - Infrastructure
# 151    AGPU            Axe Compute Inc.  Software - Infrastructure
# 163      AI                 C3.ai, Inc.  Software - Infrastructure
# 173    AIOT            PowerFleet, Inc.  Software - Infrastructure
# ...     ...                         ...                        ...
# 5461   YEXT                  Yext, Inc.  Software - Infrastructure
# 5483   YYAI                  AiRWA Inc.  Software - Infrastructure
# 5495   ZENA              ZenaTech, Inc.  Software - Infrastructure
# 5499   ZETA  Zeta Global Holdings Corp.  Software - Infrastructure
# 5518     ZS               Zscaler, Inc.  Software - Infrastructure
#
#         marketCap
# 56     4052904956
# 122     770825220
# 151       7431800
# 163    1461019057
# 173     479825646
# ...           ...
# 5461    656462364
# ...

# %%
filtering = we[we['marketCap']>10000000000]

# %%
filtering = we[we['marketCap']<2*10**9]

# %%
filtering
# Out:
#      ticker                                   name  \
# 2      AACB             Artius II Acquisition Inc.
# 3      AACG                  ATA Creativity Global
# 5      AAME          Atlantic American Corporation
# 6      AAMI          Acadian Asset Management Inc.
# 12     AARD            Aardvark Therapeutics, Inc.
# ...     ...                                    ...
# 5525   ZURA                       Zura Bio Limited
# 5526   ZVIA                              Zevia PBC
# 5527   ZVRA               Zevra Therapeutics, Inc.
# 5529   ZYBT  Zhengye Biotechnology Holding Limited
# 5530   ZYME                         Zymeworks Inc.
#
#                                       industry   marketCap
# 2                              Shell Companies   287000820
# 3                Education & Training Services    38454209
# 5                             Insurance - Life    53440737
# 6                             Asset Management  1867944067
# ...

# %%
df
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 0    2023-02-13  149.909063  151.268582  148.676683  151.209900   925400
# 1    2023-02-14  150.955609  152.334694  148.128982  149.684113   895400
# 2    2023-02-15  148.882104  148.979917  147.004208  148.422409   982400
# 3    2023-02-16  145.546896  146.867299  144.001540  145.028519  1101700
# 4    2023-02-17  144.030900  145.674069  143.277795  145.008972  1194800
# ..          ...         ...         ...         ...         ...      ...
# 271  2026-02-06   10.420000   10.450000   10.420000   10.430000    37000
# 272  2026-02-09   10.420000   10.440000   10.420000   10.440000     5300
# 273  2026-02-10   10.420000   10.440000   10.390000   10.440000   192500
# 274  2026-02-11   10.420000   10.440000   10.420000   10.435000    25100
# 275  2026-02-12   10.430000   10.430000   10.420000   10.420000     8100
#
#      is_earnings_day  EPS Estimate  Reported EPS  Surprise(%)  \
# ...

# %%
mcaps_of_value = df[df['ticker'].isin(filtering['ticker'])]

# %%
to_test = mcaps_of_value[mcaps_of_value['Date']>'2024-08-01']

# %%
to_test.groupby('industry').count()
# Out:
#                              Date  Open  High   Low  Close  Volume  \
# industry
# Advertising Agencies         1920  1920  1920  1920   1920    1920
# Aerospace & Defense          1320  1320  1320  1320   1320    1320
# Agricultural Inputs           768   768   768   768    768     768
# Airlines                      384   384   384   384    384     384
# Airports & Air Services       384   384   384   384    384     384
# ...                           ...   ...   ...   ...    ...     ...
# Travel Services                79    79    79    79     79      79
# Uranium                       384   384   384   384    384     384
# Utilities - Regulated Water   768   768   768   768    768     768
# Utilities - Renewable         768   768   768   768    768     768
# Waste Management             1536  1536  1536  1536   1536    1536
#
#                              is_earnings_day  EPS Estimate  Reported EPS  \
# industry
# ...

# %%
getit = to_test[to_test['is_earnings_day']==True]

# %%
getit[getit['EPS Estimate']>getit['Reported EPS']].sort_values(by='Reported EPS').groupby('industry').count().sort_values(by='ticker')
# Out:
#                                           Date  Open  High  Low  Close  \
# industry
# Auto & Truck Dealerships                     1     1     1    1      1
# Farm & Heavy Construction Machinery          1     1     1    1      1
# Education & Training Services                1     1     1    1      1
# Insurance - Property & Casualty              1     1     1    1      1
# Electronic Components                        1     1     1    1      1
# Drug Manufacturers - General                 1     1     1    1      1
# Medical Distribution                         1     1     1    1      1
# Leisure                                      1     1     1    1      1
# Semiconductor Equipment & Materials          1     1     1    1      1
# Medical Instruments & Supplies               1     1     1    1      1
# Utilities - Regulated Water                  1     1     1    1      1
# Insurance - Specialty                        2     2     2    2      2
# ...

# %%
df
# Out:
#            Date        Open        High         Low       Close   Volume  \
# 0    2023-02-13  149.909063  151.268582  148.676683  151.209900   925400
# 1    2023-02-14  150.955609  152.334694  148.128982  149.684113   895400
# 2    2023-02-15  148.882104  148.979917  147.004208  148.422409   982400
# 3    2023-02-16  145.546896  146.867299  144.001540  145.028519  1101700
# 4    2023-02-17  144.030900  145.674069  143.277795  145.008972  1194800
# ..          ...         ...         ...         ...         ...      ...
# 271  2026-02-06   10.420000   10.450000   10.420000   10.430000    37000
# 272  2026-02-09   10.420000   10.440000   10.420000   10.440000     5300
# 273  2026-02-10   10.420000   10.440000   10.390000   10.440000   192500
# 274  2026-02-11   10.420000   10.440000   10.420000   10.435000    25100
# 275  2026-02-12   10.430000   10.430000   10.420000   10.420000     8100
#
#      is_earnings_day  EPS Estimate  Reported EPS  Surprise(%)  \
# ...
